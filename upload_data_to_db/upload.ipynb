# %%
from pymongo.mongo_client import MongoClient
import pandas as pd
import json

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# uniform resource indentifier
uri = "mongodb+srv://piyush:12345@aluminium.vlfws.mongodb.net/?retryWrites=true&w=majority&appName=Aluminium"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# create database name and collection name
DATABASE_NAME="pwskills"
COLLECTION_NAME="Aluminium"

# %%
# read the data as a dataframe
df=pd.read_csv(r"E:\Aluminium_rod_quality_prediction\notebooks\edited_aluminium_data.csv")
#df=df.drop("Unnamed: 0",axis=1)

# %%
df.head()
# Out:
#    chemical_composition  casting_temp  cooling_water_temp  casting_speed  \
# 0              0.959970    657.620099           48.686840       2.182599
# 1              1.040920    711.691129           53.141757       1.526594
# 2              1.057989    650.444731           56.499446       2.490338
# 3              0.972297    718.558292           46.861829       2.646371
# 4              0.949149    678.634795           47.271255       2.650129
#
#    entry_temp  emulsion_temp  emulsion_pressure  emulsion_concentration  \
# 0  433.498540      79.620419           0.785194                6.574484
# 1  469.959123      35.222152           0.986792                8.350478
# 2  457.781378      30.020252           0.778450                9.028530
# 3  471.479307      74.591692           1.644531                8.418320
# 4  446.115749      32.353430           1.878254                8.842814
#
#    rod_quench_pressure         UTS  elongation  conductivity  rod_quality
# ...

# %%
# Convert the data into json
json_record=list(json.loads(df.T.to_json()).values())

# %%
json_record
# Out:
# [{'chemical_composition': 0.9599697936,
#   'casting_temp': 657.6200987605,
#   'cooling_water_temp': 48.6868401493,
#   'casting_speed': 2.1825991134,
#   'entry_temp': 433.498539606,
#   'emulsion_temp': 79.6204191495,
#   'emulsion_pressure': 0.7851943588,
#   'emulsion_concentration': 6.5744836078,
#   'rod_quench_pressure': 2.8796566307,
#   'UTS': 130.640476793,
#   'elongation': 11.1868164558,
#   'conductivity': 47.2288503242,
#   'rod_quality': -1.0},
#  {'chemical_composition': 1.0409201596,
#   'casting_temp': 711.6911291824,
#   'cooling_water_temp': 53.1417573056,
#   'casting_speed': 1.526593531,
#   'entry_temp': 469.9591233388,
#   'emulsion_temp': 35.2221515952,
#   'emulsion_pressure': 0.9867920476,
#   'emulsion_concentration': 8.3504782508,
#   'rod_quench_pressure': 4.8107341609,
#   'UTS': 135.298939312,
#   'elongation': 10.8093250935,
#   'conductivity': 46.4621075478,
#   'rod_quality': 1.0},
#  {'chemical_composition': 1.05798942,
# ...

# %%
#now dump the data into the database
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
# Out:
# InsertManyResult([ObjectId('6703f311565abfd4ddb18344'), ObjectId('6703f311565abfd4ddb18345'), ObjectId('6703f311565abfd4ddb18346'), ObjectId('6703f311565abfd4ddb18347'), ObjectId('6703f311565abfd4ddb18348'), ObjectId('6703f311565abfd4ddb18349'), ObjectId('6703f311565abfd4ddb1834a'), ObjectId('6703f311565abfd4ddb1834b'), ObjectId('6703f311565abfd4ddb1834c'), ObjectId('6703f311565abfd4ddb1834d'), ObjectId('6703f311565abfd4ddb1834e'), ObjectId('6703f311565abfd4ddb1834f'), ObjectId('6703f311565abfd4ddb18350'), ObjectId('6703f311565abfd4ddb18351'), ObjectId('6703f311565abfd4ddb18352'), ObjectId('6703f311565abfd4ddb18353'), ObjectId('6703f311565abfd4ddb18354'), ObjectId('6703f311565abfd4ddb18355'), ObjectId('6703f311565abfd4ddb18356'), ObjectId('6703f311565abfd4ddb18357'), ObjectId('6703f311565abfd4ddb18358'), ObjectId('6703f311565abfd4ddb18359'), ObjectId('6703f311565abfd4ddb1835a'), ObjectId('6703f311565abfd4ddb1835b'), ObjectId('6703f311565abfd4ddb1835c'), ObjectId('6703f311565abfd4ddb1
# ...
